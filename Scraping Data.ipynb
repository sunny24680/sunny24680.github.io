# %%
import csv
import requests
import json

summoners = {}
with open('summoners.json') as f:
    summoners = json.load(f)
API_KEY = "RGAPI-dcb0bedb-f389-4a59-b739-e4464191d7df"

# %%
sums = {}
m = 0
matchIds = []
with open('summoners.json') as f:
    sums = json.load(f)

acctId = []
for name in sums:
    acctId.append(sums[name]['accountId'])

for x in range(0,800):
    acctI = acctId[x]
    print("player = "+acctI)
    API_ENDPOINT = "https://na1.api.riotgames.com/lol/match/v4/matchlists/by-account/"+acctI+"?queue=420&api_key="+API_KEY
    r = requests.get(API_ENDPOINT)
    if (r.status_code == 200):
        matchIds.append(r.json())
        print("m = ", m)
        m = m + 1
    else : 
        print(r.json())
# Out:
# player = 0nD-WYqO4halMos8wMdQLrERyQUVAZNKKxDImaia63xncgE
# m =  0
# player = 9LbGacisEwvi0EkO7Fx5VPknrgWBvK7T-d88-FE7g_vf-A
# m =  1
# player = eV2RW-Fa45DF2H3RdUdkpSUnDIiPyI6oWQeTWgKGNwArmQ
# m =  2
# player = CgOfThKsB3OFKiQA1cuiMw9JFUis20AnnW8XImTztH4vJSWLmKcvsKBU
# {'status': {'status_code': 404, 'message': 'Not found'}}
# player = WL2UjqEhcTAVyCfRL0TeSiXI69LmvXtU1duToLEjOCu7MLE
# m =  3
# player = VkjvJhcFry9CpiBUZm4t4Z2CRtov1ff5nX0e-7OQ3YKEYg
# m =  4
# player = CNK_rIIbgnAJut9iVoFk1L9wXuc5PC6lGVCo2_GC23yMKA
# m =  5
# player = r26UBneGZpO0NOOr7OBwLBvCLTISFviwlDGFBGn88mHaDw
# m =  6
# player = qzbA8fir1uuc348uhdyuZMI2GKFjB6Vbpnr4t-fBD_a2gg
# m =  7
# player = fJESEKgmAIWm_ExMNcl4LJFrGeE5tb8wTJ6biFI5QP8RhlI
# m =  8
# player = Zribc_hMVi07IleVo7ONzNKzHcIv6MKsCAAu_z-1881XowE
# m =  9
# player = nXiVX2OZ06D50zVV5d-UQpIYpS8dGcfMhCLRA1J-F_ApEeY
# m =  10
# player = IMHHQtzw4fLRaUDYWb5kTUOb278O91ddQeqkj_fk_3BLe5M
# m =  11
# player = wW4iVlQzZMfG56yuVwFzpNfpj7BOwD69p-Ks8WyTiaqZBDE
# ...

# %%
with open('matchHistory.json', mode='w') as f:
    json.dump([], f)

with open('matchHistory.json', mode='w', encoding='utf-8') as feedsjson:
    json.dump(matchIds, feedsjson)

# %%
matchData = []

for x in range(0,800):
    acctId = summoners[x]['accountId']
    print("player = "+player)
    API_ENDPOINT = "https://na1.api.riotgames.com/lol/match/v4/matchlists/by-account/"+str(acctId)+"?queue=420&api_key="+API_KEY
    r = requests.get(API_ENDPOINT)
    if (r.status_code == 200):
        matchData.append(r.json)
        print("m = ", m)
        m = m + 1
    else : 
        print(r.json())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-8d3cc1e50c4b> in <module>()
#       2
#       3 for x in range(0,800):
# ----> 4     print(summoners[0])
#       5     acctId = summoners[x]['accountId']
#       6     print("player = "+player)
#
# KeyError: 0

# %%
import csv 

with open('summoners.csv', 'a') as csv_file:
    writer = csv.writer(csv_file)
    for key, value in summoner.items():
       writer.writerow([key, value])

# %%
ids = []
sums = {}
for player in summoners:
    print(summoners[player])
    temp = {}
    d = summoners[player].split('\'')
    temp['accountId'] = d[3]
    temp['puuid'] = d[7]
    temp['lvl'] = d[10][2:]
    sums[player] = temp
#    ids.append(summoners[player]['accountId'])
# Out:
# {'accountId': '0nD-WYqO4halMos8wMdQLrERyQUVAZNKKxDImaia63xncgE', 'puuid': 'QYDLl4PD5tmOtyW2scR9_7OE-eICY2RHoT1tb0A1mAyx6uo5dwYpiUh6Ozi3-FXc16Z4XalzFks4eA', 'lvl': 199}
# {'accountId': '9LbGacisEwvi0EkO7Fx5VPknrgWBvK7T-d88-FE7g_vf-A', 'puuid': 'xEzM_-3jHka156zS96fSSW0lvwuQQm1UXBroXnvxmo-1dBl935J3ykcCIyaV3MyFAxalCe-b761myg', 'lvl': 125}
# {'accountId': 'eV2RW-Fa45DF2H3RdUdkpSUnDIiPyI6oWQeTWgKGNwArmQ', 'puuid': 'Kk7nOrOGOowH6emfQgib8jNfBtXW4B6QR82YFNxJflVX-18jOUeRjYdA1s_9w8hCOTsQxVPgogN5aA', 'lvl': 134}
# {'accountId': 'CgOfThKsB3OFKiQA1cuiMw9JFUis20AnnW8XImTztH4vJSWLmKcvsKBU', 'puuid': 'ltcKd5xO6QppVkanXHhQgTa6eYSg85r12NnYIDw8rkOoJL3SFE59_9aEId_rZORMS0wlWMTvf_Iyiw', 'lvl': 18}
# {'accountId': 'WL2UjqEhcTAVyCfRL0TeSiXI69LmvXtU1duToLEjOCu7MLE', 'puuid': '41UmRD528cYkymVaKHDKIidf30wBo8Zkw6GuRrBZ21bEVciddH2pM2kKwnhoG-VDNUuVo8hKoRYCtQ', 'lvl': 78}
# ...

# %%
import json
with open('summoners.json', mode='w') as f:
    json.dump([], f)

with open('summoners.json', mode='w', encoding='utf-8') as feedsjson:
    json.dump(sums, feedsjson)

# %%
s[2:]
# Out:
# '199'

# %%
print(matchIds[1])
# Out:
# <bound method Response.json of <Response [200]>>

# %%
for Ids in matchIds:
    acctI = acctId[x]
    print("player = "+acctI)
    API_ENDPOINT = "https://na1.api.riotgames.com/lol/match/v4/matchlists/by-account/"+acctI+"?queue=420&api_key="+API_KEY
    r = requests.get(API_ENDPOINT)
    if (r.status_code == 200):
        matchIds.append(r.json)
        print("m = ", m)
        m = m + 1
    else : 
        print(r.json())

# %%
print(len(matchIds))
# Out:
# 730

# %%
with open('matchHistory.json', mode='w') as f:
    json.dump([], f)

with open('matchHistory.json', mode='w', encoding='utf-8') as feedsjson:
    json.dump(matchIds, feedsjson)

# %%
temp = {}
with open('matchHistory.json') as f:
    temp = json.load(f)

# %%
import json

API_KEY = "RGAPI-dcb0bedb-f389-4a59-b739-e4464191d7df"
temp = {}
with open('matchHistory.json') as f:
    temp = json.load(f)
    
m = 0
ma = []
for x in range(0,400):
    player = temp[x]
    print("MATCHES = "+str(len(player['matches'])))
    for match in player['matches']:
        API_ENDPOINT = "https://na1.api.riotgames.com/lol/match/v4/matches/"+str(match['gameId'])+"?api_key="+API_KEY
        r = requests.get(API_ENDPOINT)
        if (r.status_code == 200):
            ma.append(r.json())
            print("m = ", m)
            m = m + 1
        else : 
            print(r.json())
# Out:
# MATCHES = 100
# m =  0
# m =  1
# m =  2
# m =  3
# m =  4
# m =  5
# m =  6
# m =  7
# m =  8
# m =  9
# m =  10
# m =  11
# m =  12
# m =  13
# m =  14
# m =  15
# m =  16
# m =  17
# m =  18
# m =  19
# m =  20
# m =  21
# m =  22
# m =  23
# m =  24
# m =  25
# m =  26
# m =  27
# m =  28
# m =  29
# m =  30
# m =  31
# m =  32
# m =  33
# m =  34
# m =  35
# m =  36
# m =  37
# m =  38
# m =  39
# m =  40
# m =  41
# m =  42
# m =  43
# m =  44
# m =  45
# m =  46
# m =  47
# m =  48
# m =  49
# m =  50
# m =  51
# m =  52
# m =  53
# m =  54
# m =  55
# m =  56
# m =  57
# m =  58
# m =  59
# m =  60
# m =  61
# m =  62
# m =  63
# m =  64
# m =  65
# m =  66
# m =  67
# m =  68
# m =  69
# m =  70
# m =  71
# m =  72
# m =  73
# m =  74
# m =  75
# m =  76
# m =  77
# m =  78
# m =  79
# m =  80
# m =  81
# m =  82
# m =  83
# m =  84
# m =  85
# m =  86
# m =  87
# m =  88
# m =  89
# m =  90
# m =  91
# m =  92
# m =  93
# m =  94
# m =  95
# m =  96
# m =  97
# m =  98
# ...

# %%
with open('newMatchData.json', mode='w') as f:
    json.dump([], f)

with open('newMatchData.json', mode='w', encoding='utf-8') as feedsjson:
    json.dump(ma, feedsjson)
